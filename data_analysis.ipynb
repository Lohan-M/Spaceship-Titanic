# %%
import pandas as pd

data = pd.read_csv("train.csv")
data["GroupId"] = data["PassengerId"].str.split("_", expand=True)[0]
data["GroupSize"] = data.groupby("GroupId")["GroupId"].transform("size")

print(data.info())
print(data.duplicated().sum())
print(data.select_dtypes("number").eq(0).sum())
# Out:
# 0    0001
# 1    0002
# 2    0003
# 3    0003
# 4    0004
# Name: GroupId, dtype: str
# 0    1
# 1    1
# 2    2
# 3    2
# 4    1
# Name: GroupSize, dtype: int64
# <class 'pandas.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   str
#  1   HomePlanet    8492 non-null   str
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   str
#  4   Destination   8511 non-null   str
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   str
#  13  Transported   8693 non-null   bool
#  14  GroupId       8693 non-null   str
#  15  GroupSize     8693 non-null   int64
# dtypes: bool(1), float64(6), int64(1), object(2), str(6)
# memory usage: 1.0+ MB
# None
# 0
# Age              178
# RoomService     5577
# FoodCourt       5456
# ShoppingMall    5587
# Spa             5324
# VRDeck          5495
# GroupSize          0
# dtype: int64
